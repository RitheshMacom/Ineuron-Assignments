# %% [markdown]
# ## Python basics 10

# %% [markdown]
# ### 1.How do you distinguish between shutil.copy() and shutil.copytree()?¶

# %%
#shutil.copy : Copies a single file
#shutil.copytree() : will copy an entire folder and every folder and file contained in it

# %% [markdown]
# ### 2. What function is used to rename files ?

# %%
#import os
#os.rename("text.txt","testnew.txt")

# %% [markdown]
# ### 3. What is the difference between the delete functions in the send2trash and shutil modules?

# %%
#send2trash mudule used to send  files or folders to recycle bin or trash, 
#A TrashPermissionError exception is raised, in case a file could not be deleted due to permission error or any other unexpected reason.

#Shutil module by using shutil.retree(): function deltes files or folders permanently
#The operation cannot be undone if there were any accidental deletion performed

# %% [markdown]
# ### 4. ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?¶

# %% [raw]
# from zipfile import Zipfile
# with ZipFile(file_name, 'r') as zip
# #this code will open specified zipfile for us. we can use zip objext to preform other operation the ziplife like zip.read()

# %% [markdown]
# ### 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
import os, shutil

def selectiveCopy(source, extensions, destFolder):
    folder = os.path.abspath(source)
    destFolder = os.path.abspath(destFolder)
    print('Looking in', source, 'for files with extensions of', ', '.join(extensions))
    for foldername, subfolders, filenames in os.walk(source):
        for filename in filenames:
            name, extension = os.path.splitext(filename)
            if extension in extensions:
                fileAbsPath = foldername + os.path.sep + filename
                print('Coping', fileAbsPath, 'to', destFolder)
                shutil.copy(fileAbsPath, destFolder)

extensions = ['.mp4', '.pdf','.jpg']
source = "C:\\Users\\Admin"
destFolder = "C:\\Users\\Admin\\dest"
selectiveCopy(source, extensions, destFolder)
# Out:
# Looking in C:\Users\Admin for files with extensions of .mp4, .pdf, .jpg
# Coping C:\Users\Admin\2x2.jpg to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_entry.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_entry_acl.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_entry_linkify.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_entry_misc.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_entry_paths.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_entry_perms.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_entry_stat.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_entry_time.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_read.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_read_add_passphrase.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_read_data.3.pdf to C:\Users\Admin\dest
# Coping C:\Users\Admin\archive_read_disk.3.pdf to C:\Users\Admin\dest
# ...
